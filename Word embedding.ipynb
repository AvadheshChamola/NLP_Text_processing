# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
voc_size=10000

# %%
onehot_repr=[one_hot(words,voc_size) for words in sent]

# %%
onehot_repr
# Out:
# [[9936, 9109, 3530, 8813],
#  [9936, 9109, 3530, 4444],
#  [9936, 3665, 3530, 6802],
#  [7266, 9250, 9816, 2986, 1488],
#  [7266, 9250, 9816, 2986, 5000],
#  [5275, 9936, 6814, 3530, 3664],
#  [178, 2347, 1819, 2986]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np

# %%
sent_len=8
embedding_doc=pad_sequences(onehot_repr,padding='pre',maxlen=sent_len)
embedding_doc
# Out:
# array([[   0,    0,    0,    0, 9936, 9109, 3530, 8813],
#        [   0,    0,    0,    0, 9936, 9109, 3530, 4444],
#        [   0,    0,    0,    0, 9936, 3665, 3530, 6802],
#        [   0,    0,    0, 7266, 9250, 9816, 2986, 1488],
#        [   0,    0,    0, 7266, 9250, 9816, 2986, 5000],
#        [   0,    0,    0, 5275, 9936, 6814, 3530, 3664],
#        [   0,    0,    0,    0,  178, 2347, 1819, 2986]], dtype=int32)

# %%
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,10,input_length=sent_len))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 8, 10)             100000
# =================================================================
# Total params: 100,000
# Trainable params: 100,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.predict(embedding_doc)
# Out:
# array([[[-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [ 0.03983277, -0.01416274,  0.02311105, -0.02270031,
#           0.04936402,  0.00415971, -0.03612595, -0.02868806,
#          -0.00745363,  0.01350326],
#         [ 0.02247646, -0.00318173, -0.02681469,  0.01399699,
#           0.00312921, -0.01236309, -0.02886707, -0.02618539,
#           0.04884877,  0.01705289],
#         [-0.00088215,  0.04700868, -0.04635614, -0.01220453,
#           0.03097488,  0.03694418,  0.02125138,  0.0407302 ,
#          -0.01203482,  0.01154953],
#         [-0.03648852, -0.01648013,  0.0367651 ,  0.02028814,
#           0.01554631,  0.00507503, -0.01873374,  0.01310224,
#          -0.02563289,  0.00600152]],
#
#        [[-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [ 0.03983277, -0.01416274,  0.02311105, -0.02270031,
#           0.04936402,  0.00415971, -0.03612595, -0.02868806,
#          -0.00745363,  0.01350326],
#         [ 0.02247646, -0.00318173, -0.02681469,  0.01399699,
#           0.00312921, -0.01236309, -0.02886707, -0.02618539,
#           0.04884877,  0.01705289],
#         [-0.00088215,  0.04700868, -0.04635614, -0.01220453,
#           0.03097488,  0.03694418,  0.02125138,  0.0407302 ,
#          -0.01203482,  0.01154953],
#         [-0.00412605, -0.02943332,  0.04826334, -0.01665121,
#           0.00335246,  0.03947325,  0.0350349 , -0.03977378,
#           0.03067967, -0.04971352]],
#
#        [[-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [ 0.03983277, -0.01416274,  0.02311105, -0.02270031,
#           0.04936402,  0.00415971, -0.03612595, -0.02868806,
#          -0.00745363,  0.01350326],
#         [ 0.00421027,  0.02882296,  0.03219608,  0.04342768,
#          -0.00312778,  0.02710133,  0.03952629,  0.01795136,
#          -0.0357249 , -0.00196986],
#         [-0.00088215,  0.04700868, -0.04635614, -0.01220453,
#           0.03097488,  0.03694418,  0.02125138,  0.0407302 ,
#          -0.01203482,  0.01154953],
#         [ 0.02778887, -0.03224574,  0.02444139,  0.01950809,
#          -0.04444355,  0.04862218, -0.02202013,  0.01159675,
#          -0.00439916, -0.00131538]],
#
#        [[-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.03796499, -0.00805056,  0.00673749, -0.00141506,
#           0.0456881 , -0.03828184,  0.00613119,  0.04893165,
#           0.0337475 ,  0.01282293],
#         [-0.01002331,  0.04383551, -0.0354378 ,  0.02210752,
#          -0.03767725,  0.03841389, -0.03516791,  0.01687698,
#           0.00845181,  0.00713177],
#         [-0.01473385,  0.01909793, -0.04590095, -0.02283862,
#           0.043107  ,  0.01423587, -0.02120512,  0.0093626 ,
#          -0.04552106,  0.03636492],
#         [ 0.01052474, -0.03188322, -0.0141073 ,  0.03946563,
#          -0.01965776,  0.01369624, -0.01125687,  0.00472788,
#          -0.00066938,  0.0059889 ],
#         [-0.00626018,  0.02556671,  0.03256011, -0.02821122,
#          -0.03812624, -0.00877806, -0.04173591, -0.01621573,
#           0.04116778, -0.01067861]],
#
#        [[-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.03796499, -0.00805056,  0.00673749, -0.00141506,
#           0.0456881 , -0.03828184,  0.00613119,  0.04893165,
#           0.0337475 ,  0.01282293],
#         [-0.01002331,  0.04383551, -0.0354378 ,  0.02210752,
#          -0.03767725,  0.03841389, -0.03516791,  0.01687698,
#           0.00845181,  0.00713177],
#         [-0.01473385,  0.01909793, -0.04590095, -0.02283862,
#           0.043107  ,  0.01423587, -0.02120512,  0.0093626 ,
#          -0.04552106,  0.03636492],
#         [ 0.01052474, -0.03188322, -0.0141073 ,  0.03946563,
#          -0.01965776,  0.01369624, -0.01125687,  0.00472788,
#          -0.00066938,  0.0059889 ],
#         [ 0.03826371,  0.0255946 , -0.04631469,  0.02073285,
#          -0.01944654,  0.04833157, -0.04543166,  0.01102203,
#          -0.02232482,  0.04036633]],
#
#        [[-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [ 0.00941987, -0.01763714,  0.00514213, -0.00141605,
#          -0.03510582,  0.04355141, -0.00819372, -0.00237303,
#          -0.03689758, -0.01836079],
#         [ 0.03983277, -0.01416274,  0.02311105, -0.02270031,
#           0.04936402,  0.00415971, -0.03612595, -0.02868806,
#          -0.00745363,  0.01350326],
#         [ 0.02421167, -0.00353907, -0.02219347,  0.02108519,
#           0.01779201,  0.03908651, -0.00874548,  0.03585061,
#           0.00776862, -0.01735842],
#         [-0.00088215,  0.04700868, -0.04635614, -0.01220453,
#           0.03097488,  0.03694418,  0.02125138,  0.0407302 ,
#          -0.01203482,  0.01154953],
#         [-0.0133958 , -0.01453195,  0.04794474, -0.00748993,
#           0.04455927,  0.02520135, -0.03238536, -0.0084982 ,
#           0.00592189,  0.02566332]],
#
#        [[-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02324133, -0.0486923 , -0.03953626,  0.00224777,
#           0.03803394, -0.0356331 , -0.03419679, -0.03431889,
#          -0.01500908,  0.04752834],
#         [-0.02426739, -0.03454393, -0.00520129,  0.01705479,
#          -0.01911529,  0.01833506, -0.00239642,  0.04380498,
#          -0.015683  , -0.0043798 ],
#         [-0.03387816, -0.04847053, -0.03584298, -0.02885877,
#          -0.04548644, -0.03103586, -0.0029871 ,  0.02385848,
#           0.00682546, -0.02238698],
#         [-0.02493485, -0.00987284,  0.03137073, -0.03736863,
#          -0.04756952, -0.03890548, -0.03800998, -0.04319832,
#           0.02425152,  0.04365274],
#         [ 0.01052474, -0.03188322, -0.0141073 ,  0.03946563,
#          -0.01965776,  0.01369624, -0.01125687,  0.00472788,
#          -0.00066938,  0.0059889 ]]], dtype=float32)
